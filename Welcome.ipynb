# %%
def main():
    name=input("How would I call you?")
    name=name.title().strip()
    hello(name)
def hello(name='dear reader'):
    print('Hello,',name,',welcome to my python learning documentary!')
main()
# Out:
# How would I call you?   pretzel 1
# Hello, Pretzel 1 ,welcome to my python learning documentary!
